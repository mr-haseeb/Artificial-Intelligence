# %% [markdown]
# # what is pandas groupby
# ### pandas groupby function is used for split the data into groups
# ### based on some criteria

# %%
# any groupby operation invlove one of the following operations on the
# original object

# split the object 
# apply a function
# combine the result

# %%
import pandas as pd
df=pd.read_csv('csv_files/Fortune_10.csv')
df
# Out:
#    ID             Name            Companies  Inception        Revenue  \
# 0   1          Lamtone          IT Services        2009  $11,757,018
# 1   2        Stripfind   Financial Services        2010  $12,329,371
# 2   3  Canecorporation               Health        2012  $10,597,009
# 3   4         Mattouch          IT Services        2013  $14,026,934
# 4   5        Techdrill                  NaN        2009  $10,573,990
# 5   6         Techline                  NaN        2006  $13,898,119
# 6   7          Cityace                  NaN        2010   $9,254,614
# 7   8   Kayelectronics                  NaN        2009   $9,451,943
# 8   9          Ganzlax          IT Services        2011  $14,001,180
# 9  10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a4fc9c00d097> in <module>
# ----> 1 df.groupby()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7626
#    7627         if level is None and by is None:
# -> 7628             raise TypeError("You have to supply one of 'by' and 'level'")
#    7629         axis = self._get_axis_number(axis)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#
# TypeError: You have to supply one of 'by' and 'level'
